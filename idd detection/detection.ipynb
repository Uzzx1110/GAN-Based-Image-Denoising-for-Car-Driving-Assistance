# %%
import tensorflow as tf
import os
import xml.etree.ElementTree as ET
import numpy as np
from typing import List, Dict, Tuple

# Handle different TF versions
try:
    AUTOTUNE = tf.data.AUTOTUNE  # TF 2.4+
except AttributeError:
    AUTOTUNE = tf.data.experimental.AUTOTUNE  # TF 2.0-2.3

class IDDFGVDLoader:
    def __init__(self, base_dir: str):
        """
        Initialize the data loader for IDD-FGVD dataset with XML annotations
        
        Args:
            base_dir: Path to the root directory (idd_fgvd)
        """
        self.base_dir = base_dir
        
        # Verify directory structure
        self._verify_directory_structure()
        
        # Get file lists
        self.train_files = self._get_file_pairs('train')
        self.val_files = self._get_file_pairs('val')
        self.test_files = self._get_file_pairs('test')
        
        # Initialize label mapping
        self.label_map = self._create_label_map()
        if not self.label_map:
            raise ValueError("No valid labels found in the dataset!")
        self.reverse_label_map = {v: k for k, v in self.label_map.items()}
        
        print(f"\nDataset initialized successfully with:")
        print(f"- {len(self.train_files)} training samples")
        print(f"- {len(self.val_files)} validation samples")
        print(f"- {len(self.test_files)} test samples")
        print(f"- {len(self.label_map)} classes: {self.label_map}\n")

    def _verify_directory_structure(self):
        """Verify the dataset directory structure"""
        required_dirs = [
            ('train', 'images'),
            ('train', 'annos'),
            ('val', 'images'),
            ('val', 'annos'),
            ('test', 'images'),
            ('test', 'annos')
        ]
        
        missing_dirs = []
        for split, subdir in required_dirs:
            dir_path = os.path.join(self.base_dir, split, subdir)
            if not os.path.exists(dir_path):
                missing_dirs.append(dir_path)
        
        if missing_dirs:
            raise FileNotFoundError(
                f"Missing required directories:\n" + 
                "\n".join(missing_dirs) +
                "\nPlease check your dataset structure."
            )

    def _get_file_pairs(self, split: str) -> List[Tuple[str, str]]:
        """Get matching image and XML annotation file pairs for a split"""
        image_dir = os.path.join(self.base_dir, split, 'images')
        anno_dir = os.path.join(self.base_dir, split, 'annos')
        
        # Get sorted lists of files
        image_files = sorted([
            f for f in os.listdir(image_dir) 
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ])
        anno_files = sorted([
            f for f in os.listdir(anno_dir)
            if f.lower().endswith('.xml')
        ])
        
        # Create pairs by matching base names
        pairs = []
        for img_file in image_files:
            base_name = os.path.splitext(img_file)[0]
            anno_file = f"{base_name}.xml"
            
            if anno_file in anno_files:
                pairs.append((
                    os.path.join(image_dir, img_file),
                    os.path.join(anno_dir, anno_file)
                ))
            else:
                print(f"Warning: No annotation found for {img_file}")
        
        if not pairs:
            raise ValueError(f"No valid image-annotation pairs found in {split} split")
            
        return pairs

    def _create_label_map(self) -> Dict[str, int]:
        """Create mapping from simplified labels to unique integers"""
        all_labels = set()
        
        for split in ['train', 'val', 'test']:
            anno_dir = os.path.join(self.base_dir, split, 'annos')
            
            for anno_file in os.listdir(anno_dir):
                if not anno_file.endswith('.xml'):
                    continue
                
                try:
                    tree = ET.parse(os.path.join(anno_dir, anno_file))
                    root = tree.getroot()
                    
                    for obj in root.findall('object'):
                        name = obj.find('name')
                        if name is None:
                            continue
                            
                        # Simplify label (e.g., "car_honda" -> "car")
                        full_label = name.text
                        simplified = full_label.split('_')[0]
                        all_labels.add(simplified)
                except Exception as e:
                    print(f"Error processing {anno_file}: {str(e)}")
                    continue
        
        return {label: idx for idx, label in enumerate(sorted(all_labels), start=1)}

    def _load_image(self, img_path: tf.Tensor) -> tf.Tensor:
        """Load and normalize an image"""
        img = tf.io.read_file(img_path)
        img = tf.image.decode_image(img, channels=3, expand_animations=False)
        img = tf.cast(img, tf.float32)
        return img

    def _parse_annotations(self, anno_path: tf.Tensor) -> Dict:
        """Parse XML annotations into tensors"""
        def _parse_xml(path):
            path = path.numpy().decode('utf-8')
            tree = ET.parse(path)
            root = tree.getroot()
            
            boxes = []
            label_ids = []
            
            for obj in root.findall('object'):
                name = obj.find('name')
                bbox = obj.find('bndbox')
                
                if name is None or bbox is None:
                    continue
                
                # Get simplified label ID
                full_label = name.text
                simplified = full_label.split('_')[0]
                
                # Convert bbox coordinates to float32
                x1 = float(bbox.find('xmin').text)
                y1 = float(bbox.find('ymin').text)
                x2 = float(bbox.find('xmax').text)
                y2 = float(bbox.find('ymax').text)
                
                boxes.append([x1, y1, x2, y2])
                label_ids.append(self.label_map[simplified])
            
            return (
                np.array(boxes, dtype=np.float32),
                np.array(label_ids, dtype=np.int32)
            )
        
        # Parse using tf.py_function
        boxes, labels = tf.py_function(
            _parse_xml,
            [anno_path],
            [tf.float32, tf.int32]
        )
        
        # Create unique image ID
        image_id = tf.strings.to_hash_bucket_fast(anno_path, num_buckets=2**31)
        
        return {
            'boxes': boxes,
            'labels': labels,
            'image_id': tf.cast(image_id, tf.int64)
        }

    def _process_sample(self, img_path: tf.Tensor, anno_path: tf.Tensor) -> Tuple[tf.Tensor, Dict]:
        """Process a single image-annotation pair"""
        img = self._load_image(img_path)
        target = self._parse_annotations(anno_path)
        
        # Add image dimensions
        img_shape = tf.shape(img)
        target['original_size'] = tf.stack([img_shape[0], img_shape[1]])
        target['size'] = tf.identity(target['original_size'])
        
        return img, target

    def get_dataset(self, split: str = 'train', batch_size: int = 1) -> tf.data.Dataset:
        """
        Get a TensorFlow Dataset for the specified split
        
        Args:
            split: One of 'train', 'val', or 'test'
            batch_size: Batch size (recommend 1 for variable-sized images)
        
        Returns:
            A TensorFlow Dataset yielding (image, target) pairs
        """
        if split not in ['train', 'val', 'test']:
            raise ValueError("Split must be 'train', 'val', or 'test'")
            
        files = getattr(self, f"{split}_files")
        
        # Create dataset from paths
        img_paths = tf.constant([f[0] for f in files], dtype=tf.string)
        anno_paths = tf.constant([f[1] for f in files], dtype=tf.string)
        
        dataset = tf.data.Dataset.from_tensor_slices((img_paths, anno_paths))
        
        # Process samples in parallel
        dataset = dataset.map(
            self._process_sample,
            num_parallel_calls=AUTOTUNE
        )
        
        # Batch handling
        if batch_size > 1:
            dataset = dataset.batch(batch_size)
        else:
            # Add batch dimension for batch_size=1
            dataset = dataset.map(
                lambda x, y: (tf.expand_dims(x, 0), {
                    k: tf.expand_dims(v, 0) for k, v in y.items()
                }),
                num_parallel_calls=AUTOTUNE
            )
        
        return dataset.prefetch(buffer_size=AUTOTUNE)


# Example usage
if __name__ == "__main__":
    try:
        # Initialize with your dataset path
        loader = IDDFGVDLoader(base_dir=r"C:\Users\Sejal Hanmante\OneDrive\Desktop\idd detection\IDD_FGVD")
        
        # Get training dataset
        train_dataset = loader.get_dataset('train')
        
        # Inspect first sample
        for images, targets in train_dataset.take(1):
            print("\nFirst sample details:")
            print("Image shape:", images.shape)
            print("Boxes:", targets['boxes'].numpy())
            print("Labels:", targets['labels'].numpy())
            print("Original size:", targets['original_size'].numpy())
            
            # Convert numeric labels back to text
            print("Label names:", [
                loader.reverse_label_map[label] 
                for label in targets['labels'].numpy().flatten()
            ])
            
    except Exception as e:
        print(f"\nError: {str(e)}")
        print("Please verify:")
        print("1. The base directory path is correct")
        print("2. The dataset follows the required structure")
        print("3. Annotation files are in Pascal VOC XML format")
# Out:
# Dataset initialized successfully with:
# - 3535 training samples
# - 884 validation samples
# - 1083 test samples
# - 7 classes: {'autorickshaw': 1, 'bus': 2, 'car': 3, 'mini-bus': 4, 'motorcycle': 5, 'scooter': 6, 'truck': 7}
#
#
# First sample details:
# Image shape: (1, 1080, 1920, 3)
# Boxes: [[[ 996.    619.   1086.    752.  ]
#   [ 855.6   565.    958.9   688.63]]]
# Labels: [[5 3]]
# Original size: [[1080 1920]]
# Label names: ['motorcycle', 'car']

# %%
# !git clone https://github.com/roboflow/inference.git
# Out:
# Cloning into 'inference'...
# Updating files:  32% (590/1827)
# Updating files:  33% (603/1827)
# Updating files:  34% (622/1827)
# Updating files:  35% (640/1827)
# Updating files:  36% (658/1827)
# Updating files:  37% (676/1827)
# Updating files:  38% (695/1827)
# Updating files:  39% (713/1827)
# Updating files:  40% (731/1827)
# Updating files:  41% (750/1827)
# Updating files:  42% (768/1827)
# Updating files:  43% (786/1827)
# Updating files:  44% (804/1827)
# Updating files:  45% (823/1827)
# Updating files:  46% (841/1827)
# Updating files:  47% (859/1827)
# Updating files:  48% (877/1827)
# Updating files:  49% (896/1827)
# Updating files:  50% (914/1827)
# Updating files:  51% (932/1827)
# Updating files:  52% (951/1827)
# Updating files:  53% (969/1827)
# Updating files:  54% (987/1827)
# Updating files:  55% (1005/1827)
# Updating files:  56% (1024/1827)
# Updating files:  57% (1042/1827)
# Updating files:  58% (1060/1827)
# Updating files:  59% (1078/1827)
# Updating files:  60% (1097/1827)
# Updating files:  61% (1115/1827)
# Updating files:  62% (1133/1827)
# Updating files:  63% (1152/1827)
# Updating files:  64% (1170/1827)
# Updating files:  65% (1188/1827)
# Updating files:  66% (1206/1827)
# Updating files:  67% (1225/1827)
# Updating files:  68% (1243/1827)
# Updating files:  69% (1261/1827)
# Updating files:  69% (1273/1827)
# Updating files:  70% (1279/1827)
# Updating files:  71% (1298/1827)
# Updating files:  72% (1316/1827)
# Updating files:  73% (1334/1827)
# Updating files:  74% (1352/1827)
# Updating files:  75% (1371/1827)
# Updating files:  76% (1389/1827)
# Updating files:  77% (1407/1827)
# Updating files:  78% (1426/1827)
# Updating files:  79% (1444/1827)
# Updating files:  80% (1462/1827)
# Updating files:  80% (1468/1827)
# Updating files:  81% (1480/1827)
# Updating files:  82% (1499/1827)
# Updating files:  83% (1517/1827)
# Updating files:  84% (1535/1827)
# Updating files:  85% (1553/1827)
# Updating files:  86% (1572/1827)
# Updating files:  87% (1590/1827)
# Updating files:  88% (1608/1827)
# Updating files:  89% (1627/1827)
# Updating files:  90% (1645/1827)
# Updating files:  91% (1663/1827)
# Updating files:  92% (1681/1827)
# Updating files:  93% (1700/1827)
# Updating files:  94% (1718/1827)
# Updating files:  95% (1736/1827)
# Updating files:  96% (1754/1827)
# Updating files:  97% (1773/1827)
# Updating files:  98% (1791/1827)
# Updating files:  99% (1809/1827)
# Updating files: 100% (1827/1827)
# Updating files: 100% (1827/1827), done.

# %% [markdown]
# RT-DETR

# %%
import os
import xml.etree.ElementTree as ET

def update_class_names_in_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    modified = False

    for obj in root.findall('object'):
        name = obj.find('name')
        if name is not None and '_' in name.text:
            old = name.text
            name.text = name.text.split('_')[0]  # Keep only first part
            print(f"Updated '{old}' → '{name.text}' in {os.path.basename(xml_file)}")
            modified = True

    if modified:
        tree.write(xml_file)

def update_all_xmls_in_dir(root_dir):
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.xml'):
                full_path = os.path.join(subdir, file)
                update_class_names_in_xml(full_path)

# 🔁 Set this to your base annotations folder (train/val/test annos)
base_annos_dir = r"C:\Users\Sejal Hanmante\OneDrive\Desktop\idd detection\IDD_FGVD"

# This will go through all train/val/test/annos folders and update classes
for split in ['train', 'val', 'test']:
    anno_path = os.path.join(base_annos_dir, split, 'annos')
    update_all_xmls_in_dir(anno_path)

print("\n✅ All XML files updated!")
# Out:
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 0.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 0.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 1.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1.xml
# Updated 'truck_Others' → 'truck' in 1.xml
# Updated 'scooter_Honda_Aviator' → 'scooter' in 10.xml
# Updated 'car_Toyota_Qualis' → 'car' in 10.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 10.xml
# Updated 'car_Honda_City' → 'car' in 10.xml
# Updated 'car_Hyundai_I10' → 'car' in 10.xml
# Updated 'motorcycle_TVS_StarCityPlus' → 'motorcycle' in 10.xml
# Updated 'motorcycle_Bajaj_Pulsar220F' → 'motorcycle' in 10.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 10.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 10.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 100.xml
# Updated 'car_Hyundai_Santro' → 'car' in 100.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 100.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 100.xml
# Updated 'motorcycle_Bajaj_Avenger' → 'motorcycle' in 100.xml
# Updated 'car_TataMotors_Indica' → 'car' in 100.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1000.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1000.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1000.xml
# Updated 'motorcycle_Yamaha_FZS-FI' → 'motorcycle' in 1000.xml
# Updated 'car_MarutiSuzuki_Baleno' → 'car' in 1001.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1001.xml
# Updated 'car_Hyundai_Creta' → 'car' in 1001.xml
# Updated 'car_Toyota_EtiosLiva' → 'car' in 1001.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1001.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1003.xml
# Updated 'car_Toyota_Innova' → 'car' in 1003.xml
# Updated 'car_Hyundai_I10' → 'car' in 1003.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1004.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1004.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1004.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 1004.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1004.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 1004.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 1004.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1004.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1004.xml
# Updated 'car_Hyundai_Eon' → 'car' in 1005.xml
# Updated 'car_Toyota_Innova' → 'car' in 1005.xml
# Updated 'truck_Others' → 'truck' in 1005.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 1005.xml
# Updated 'car_Toyota_Etios' → 'car' in 1005.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1005.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1006.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1006.xml
# Updated 'motorcycle_Hero_HFDeluxe' → 'motorcycle' in 1006.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1006.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1006.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1006.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 1007.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1007.xml
# Updated 'car_Toyota_Etios' → 'car' in 1008.xml
# Updated 'car_Volkswagen_Polo' → 'car' in 1008.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1008.xml
# Updated 'car_Mahindra_Xylo' → 'car' in 1008.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 1008.xml
# Updated 'motorcycle_Bajaj_Discover' → 'motorcycle' in 101.xml
# Updated 'car_Hyundai_I20' → 'car' in 101.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 101.xml
# Updated 'truck_Tata' → 'truck' in 101.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1010.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1010.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1010.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1010.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 1010.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1011.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 1011.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1011.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1012.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1012.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1012.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 1012.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1012.xml
# Updated 'motorcycle_Bajaj_Avenger' → 'motorcycle' in 1012.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1012.xml
# Updated 'car_Others' → 'car' in 1016.xml
# Updated 'car_Mahindra_Verito' → 'car' in 1016.xml
# Updated 'car_Others' → 'car' in 1016.xml
# Updated 'car_Hyundai_I10' → 'car' in 1016.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1016.xml
# Updated 'car_Others' → 'car' in 1016.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1016.xml
# Updated 'car_Others' → 'car' in 1016.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1016.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1016.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1016.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1016.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1016.xml
# Updated 'truck_Mahindra' → 'truck' in 1017.xml
# Updated 'motorcycle_Bajaj_Avenger' → 'motorcycle' in 1017.xml
# Updated 'car_Honda_City' → 'car' in 1018.xml
# Updated 'car_TataMotors_Zest' → 'car' in 1019.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 102.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 102.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 102.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 102.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 102.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 102.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 102.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 102.xml
# Updated 'motorcycle_Yamaha_R15' → 'motorcycle' in 1020.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 1020.xml
# Updated 'motorcycle_Yamaha_FZ25' → 'motorcycle' in 1020.xml
# Updated 'car_Skoda_Octavia' → 'car' in 1020.xml
# Updated 'motorcycle_TVS_XL100' → 'motorcycle' in 1021.xml
# Updated 'truck_Eicher' → 'truck' in 1021.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1021.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1021.xml
# Updated 'car_Hyundai_I10' → 'car' in 1021.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1023.xml
# Updated 'motorcycle_Bajaj_Pulsar220F' → 'motorcycle' in 1023.xml
# Updated 'truck_Others' → 'truck' in 1023.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1023.xml
# Updated 'car_MarutiSuzuki_Baleno' → 'car' in 1026.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1026.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1026.xml
# Updated 'car_Toyota_EtiosLiva' → 'car' in 1026.xml
# Updated 'car_Nissan_Micra' → 'car' in 1027.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1027.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1028.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1028.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 1028.xml
# Updated 'motorcycle_Yamaha_FZS-FI' → 'motorcycle' in 1028.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1028.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1028.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1029.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1029.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1029.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1029.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1029.xml
# Updated 'scooter_Hero_Duet' → 'scooter' in 1029.xml
# Updated 'scooter_Honda_Aviator' → 'scooter' in 1029.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 103.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 103.xml
# Updated 'car_Honda_Amaze' → 'car' in 103.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1031.xml
# Updated 'truck_SML' → 'truck' in 1032.xml
# Updated 'truck_Mahindra' → 'truck' in 1032.xml
# Updated 'truck_Eicher' → 'truck' in 1032.xml
# Updated 'car_MarutiSuzuki_Eeco' → 'car' in 1033.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1034.xml
# Updated 'car_Others' → 'car' in 1034.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1036.xml
# Updated 'car_MarutiSuzuki_Baleno' → 'car' in 1036.xml
# Updated 'motorcycle_TVS_ApacheRTR160' → 'motorcycle' in 1036.xml
# Updated 'car_Honda_Civic' → 'car' in 1036.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1037.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 1037.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1037.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1037.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1038.xml
# Updated 'autorickshaw_Mahindra' → 'autorickshaw' in 1038.xml
# Updated 'truck_Tata' → 'truck' in 1038.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1038.xml
# Updated 'truck_Others' → 'truck' in 1039.xml
# Updated 'scooter_Others' → 'scooter' in 1039.xml
# Updated 'truck_Others' → 'truck' in 1039.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 1039.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 104.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 104.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 104.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 104.xml
# Updated 'car_Hyundai_Creta' → 'car' in 104.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 104.xml
# Updated 'truck_Others' → 'truck' in 1040.xml
# Updated 'truck_Mahindra' → 'truck' in 1040.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 1040.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1040.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 1041.xml
# Updated 'truck_Tata' → 'truck' in 1042.xml
# Updated 'car_Ford_Figo' → 'car' in 1042.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1042.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1042.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1042.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1042.xml
# Updated 'truck_Tata' → 'truck' in 1043.xml
# Updated 'car_Toyota_Etios' → 'car' in 1043.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1043.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 1043.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1044.xml
# Updated 'car_Honda_Amaze' → 'car' in 1044.xml
# Updated 'car_Toyota_Etios' → 'car' in 1044.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 1045.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1046.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1046.xml
# Updated 'car_Honda_City' → 'car' in 1046.xml
# Updated 'car_Toyota_Etios' → 'car' in 1046.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1046.xml
# Updated 'motorcycle_Bajaj_Discover135' → 'motorcycle' in 1046.xml
# Updated 'car_Ford_Fiesta' → 'car' in 1047.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1047.xml
# Updated 'car_Hyundai_I20' → 'car' in 1049.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1049.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1049.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1049.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 1049.xml
# Updated 'motorcycle_TVS_StarCityPlus' → 'motorcycle' in 105.xml
# Updated 'motorcycle_Yamaha_FZ25' → 'motorcycle' in 105.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 105.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 105.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1052.xml
# Updated 'truck_Tata' → 'truck' in 1052.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1052.xml
# Updated 'scooter_Yamaha_Fascino125' → 'scooter' in 1052.xml
# Updated 'car_Toyota_Etios' → 'car' in 1053.xml
# Updated 'truck_Tata' → 'truck' in 1053.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1053.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1053.xml
# Updated 'truck_Others' → 'truck' in 1054.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1054.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1054.xml
# Updated 'truck_Eicher' → 'truck' in 1055.xml
# Updated 'car_Toyota_Innova' → 'car' in 1055.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1058.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1058.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1058.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 1058.xml
# Updated 'motorcycle_TVS_ApacheRTR160' → 'motorcycle' in 1058.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1059.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1059.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 106.xml
# Updated 'car_TataMotors_Indigo' → 'car' in 1060.xml
# Updated 'car_Chevrolet_Spark' → 'car' in 1060.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 1060.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1060.xml
# Updated 'car_Hyundai_Santro' → 'car' in 1060.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1060.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1061.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1061.xml
# Updated 'motorcycle_TVS_Excel100' → 'motorcycle' in 1061.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1061.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 1061.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1061.xml
# Updated 'car_Toyota_Etios' → 'car' in 1062.xml
# Updated 'car_Hyundai_I20' → 'car' in 1062.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1062.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1062.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1062.xml
# Updated 'truck_Tata' → 'truck' in 1064.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1064.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1064.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 1065.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 1065.xml
# Updated 'car_Toyota_Etios' → 'car' in 1067.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1068.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1068.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1068.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1068.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1068.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1069.xml
# Updated 'car_Skoda_Octavia' → 'car' in 1069.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 107.xml
# Updated 'car_Toyota_Etios' → 'car' in 107.xml
# Updated 'truck_Mahindra' → 'truck' in 107.xml
# Updated 'car_Toyota_Etios' → 'car' in 107.xml
# Updated 'car_Toyota_EtiosLiva' → 'car' in 1070.xml
# Updated 'car_Hyundai_I10' → 'car' in 1070.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 1071.xml
# Updated 'truck_Mahindra' → 'truck' in 1071.xml
# Updated 'car_Honda_Amaze' → 'car' in 1071.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1071.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1073.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1073.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1073.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1073.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1073.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1073.xml
# Updated 'motorcycle_Yamaha_FZ25' → 'motorcycle' in 1073.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1073.xml
# Updated 'scooter_TVS_Wego' → 'scooter' in 1073.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1073.xml
# Updated 'motorcycle_Yamaha_FZ-V3' → 'motorcycle' in 1074.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1074.xml
# Updated 'scooter_Others' → 'scooter' in 1075.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1075.xml
# Updated 'car_Hyundai_Creta' → 'car' in 1075.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 1076.xml
# Updated 'truck_Mahindra' → 'truck' in 1076.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1076.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 1076.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1076.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1076.xml
# Updated 'car_Hyundai_I20' → 'car' in 1077.xml
# Updated 'car_Hyundai_Xcent' → 'car' in 1077.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1077.xml
# Updated 'truck_Tata' → 'truck' in 1077.xml
# Updated 'car_Others' → 'car' in 1077.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1079.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1079.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1079.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1079.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1079.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 108.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 108.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 108.xml
# Updated 'car_TataMotors_Indica' → 'car' in 108.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 108.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1080.xml
# Updated 'car_Others' → 'car' in 1080.xml
# Updated 'car_Mahindra_Scorpio' → 'car' in 1080.xml
# Updated 'car_Toyota_Etios' → 'car' in 1080.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 1080.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1080.xml
# Updated 'motorcycle_TVS_XL100' → 'motorcycle' in 1081.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1081.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 1081.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 1082.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 1082.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1083.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1083.xml
# Updated 'car_Hyundai_Xcent' → 'car' in 1083.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1084.xml
# Updated 'car_Honda_Jazz' → 'car' in 1085.xml
# Updated 'scooter_Yamaha_Fascino125' → 'scooter' in 1085.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1085.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 1086.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 1086.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 1086.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 1086.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1086.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1086.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 1086.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1086.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1086.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1087.xml
# Updated 'car_Hyundai_I10' → 'car' in 1088.xml
# Updated 'car_Toyota_Innova' → 'car' in 1088.xml
# Updated 'car_MarutiSuzuki_VitaraBrezza' → 'car' in 1088.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 1088.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 1088.xml
# Updated 'scooter_TVS_Wego' → 'scooter' in 1088.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1088.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 1089.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 109.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 109.xml
# Updated 'motorcycle_Bajaj_Pulsar220F' → 'motorcycle' in 109.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 109.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 109.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 109.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 109.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 109.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 109.xml
# Updated 'autorickshaw_TVS' → 'autorickshaw' in 1090.xml
# Updated 'car_Hyundai_Santro' → 'car' in 1090.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1090.xml
# Updated 'truck_Mahindra' → 'truck' in 1090.xml
# Updated 'car_Covered' → 'car' in 1090.xml
# Updated 'truck_Others' → 'truck' in 1091.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1091.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1091.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1092.xml
# Updated 'scooter_Honda_Aviator' → 'scooter' in 1092.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1094.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1094.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1095.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1095.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1095.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1095.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1095.xml
# Updated 'car_Honda_City' → 'car' in 1096.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1096.xml
# Updated 'car_Toyota_Etios' → 'car' in 1096.xml
# Updated 'car_Mahindra_Verito' → 'car' in 1099.xml
# Updated 'car_Hyundai_I10' → 'car' in 1099.xml
# Updated 'car_Others' → 'car' in 1099.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 11.xml
# Updated 'car_Mahindra_Xylo' → 'car' in 11.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 11.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 11.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 11.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 110.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 110.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 110.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1100.xml
# Updated 'truck_Others' → 'truck' in 1100.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1102.xml
# Updated 'car_Toyota_Innova' → 'car' in 1102.xml
# Updated 'car_Toyota_Innova' → 'car' in 1102.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1102.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1106.xml
# Updated 'car_Ford_Figo' → 'car' in 1106.xml
# Updated 'motorcycle_Bajaj_Avenger' → 'motorcycle' in 1106.xml
# Updated 'truck_Mahindra' → 'truck' in 1107.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 1107.xml
# Updated 'scooter_Yamaha_Fascino125' → 'scooter' in 1108.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 1108.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 1108.xml
# Updated 'truck_Tata' → 'truck' in 1109.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1109.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1109.xml
# Updated 'car_Toyota_Etios' → 'car' in 1109.xml
# Updated 'car_TataMotors_Nano' → 'car' in 1109.xml
# Updated 'truck_Eicher' → 'truck' in 111.xml
# Updated 'car_TataMotors_Indica' → 'car' in 111.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 111.xml
# Updated 'truck_Others' → 'truck' in 1110.xml
# Updated 'car_Hyundai_Accent' → 'car' in 1110.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 1110.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1110.xml
# Updated 'car_Toyota_Innova' → 'car' in 1110.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 1110.xml
# Updated 'car_Toyota_Etios' → 'car' in 1111.xml
# Updated 'car_Renault_Duster' → 'car' in 1111.xml
# Updated 'car_Toyota_Etios' → 'car' in 1114.xml
# Updated 'car_Ford_Figo' → 'car' in 1114.xml
# Updated 'car_Toyota_Etios' → 'car' in 1114.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1114.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 1114.xml
# Updated 'motorcycle_HeroHonda_CBZ' → 'motorcycle' in 1116.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1116.xml
# Updated 'car_Others' → 'car' in 1117.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1117.xml
# Updated 'truck_Eicher' → 'truck' in 1117.xml
# Updated 'car_Toyota_Etios' → 'car' in 1118.xml
# Updated 'car_Others' → 'car' in 1118.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1118.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1118.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1118.xml
# Updated 'truck_Eicher' → 'truck' in 1119.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1119.xml
# Updated 'motorcycle_RoyalEnfield_Bullet350' → 'motorcycle' in 1119.xml
# Updated 'truck_BharatBenz' → 'truck' in 1119.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1119.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1119.xml
# Updated 'car_Chevrolet_Spark' → 'car' in 1119.xml
# Updated 'car_MarutiSuzuki_Ignis' → 'car' in 1119.xml
# Updated 'motorcycle_Yamaha_FZS-FI' → 'motorcycle' in 112.xml
# Updated 'car_Toyota_Qualis' → 'car' in 1120.xml
# Updated 'truck_Others' → 'truck' in 1120.xml
# Updated 'motorcycle_RoyalEnfield_Bullet350' → 'motorcycle' in 1120.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1121.xml
# Updated 'car_Toyota_Innova' → 'car' in 1121.xml
# Updated 'car_TataMotors_Zest' → 'car' in 1121.xml
# Updated 'car_Toyota_Innova' → 'car' in 1121.xml
# Updated 'car_Toyota_Innova' → 'car' in 1121.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1122.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1122.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1122.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1122.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1122.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1122.xml
# Updated 'motorcycle_HeroHonda_CBZ' → 'motorcycle' in 1122.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 1122.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1124.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1125.xml
# Updated 'car_Toyota_Innova' → 'car' in 1127.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1127.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 1128.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1129.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1129.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 1129.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1129.xml
# Updated 'car_MarutiSuzuki_Ertiga' → 'car' in 113.xml
# Updated 'car_Mahindra_Reva' → 'car' in 113.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 113.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 1131.xml
# Updated 'car_Toyota_Etios' → 'car' in 1131.xml
# Updated 'car_Others' → 'car' in 1131.xml
# Updated 'car_Mahindra_Scorpio' → 'car' in 1131.xml
# Updated 'car_Others' → 'car' in 1131.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1132.xml
# Updated 'car_Others' → 'car' in 1132.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1132.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1132.xml
# Updated 'car_Mahindra_XUV500' → 'car' in 1132.xml
# Updated 'car_Mahindra_Scorpio' → 'car' in 1132.xml
# Updated 'truck_Eicher' → 'truck' in 1134.xml
# Updated 'motorcycle_RoyalEnfield_Bullet350' → 'motorcycle' in 1134.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1134.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1134.xml
# Updated 'truck_Tata' → 'truck' in 1134.xml
# Updated 'car_Hyundai_I10' → 'car' in 1134.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1136.xml
# Updated 'car_MarutiSuzuki_Eeco' → 'car' in 1136.xml
# Updated 'motorcycle_TVS_ApacheRTR160' → 'motorcycle' in 1136.xml
# Updated 'car_MarutiSuzuki_Celerio' → 'car' in 1137.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1137.xml
# Updated 'car_Toyota_Etios' → 'car' in 1137.xml
# Updated 'car_Volkswagen_Polo' → 'car' in 1137.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1138.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1138.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1138.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1138.xml
# Updated 'truck_Tata' → 'truck' in 1138.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 1139.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1139.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1139.xml
# Updated 'truck_Mahindra' → 'truck' in 114.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 114.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 114.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 114.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 114.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 114.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 114.xml
# Updated 'car_Renault_Duster' → 'car' in 1140.xml
# Updated 'motorcycle_Honda_CBHornet160R' → 'motorcycle' in 1140.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1140.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1140.xml
# Updated 'car_Toyota_Innova' → 'car' in 1140.xml
# Updated 'car_Honda_Amaze' → 'car' in 1140.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1140.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1141.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1141.xml
# Updated 'scooter_TVS_Wego' → 'scooter' in 1141.xml
# Updated 'car_MarutiSuzuki_Celerio' → 'car' in 1141.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1142.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 1142.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1142.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 1142.xml
# Updated 'motorcycle_Suzuki_Gixxer' → 'motorcycle' in 1142.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1142.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 1142.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1143.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1145.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1145.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1145.xml
# Updated 'motorcycle_TVS_XL100' → 'motorcycle' in 1146.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1146.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1146.xml
# Updated 'motorcycle_Bajaj_Platina' → 'motorcycle' in 1146.xml
# Updated 'car_Others' → 'car' in 1146.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1148.xml
# Updated 'truck_Tata' → 'truck' in 1148.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1148.xml
# Updated 'car_Ford_Ikon' → 'car' in 1148.xml
# Updated 'truck_Eicher' → 'truck' in 1148.xml
# Updated 'motorcycle_RoyalEnfield_Bullet350' → 'motorcycle' in 1148.xml
# Updated 'car_Toyota_Innova' → 'car' in 1149.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 115.xml
# Updated 'car_MarutiSuzuki_Ertiga' → 'car' in 115.xml
# Updated 'car_Hyundai_I10' → 'car' in 115.xml
# Updated 'car_Hyundai_Creta' → 'car' in 1150.xml
# Updated 'truck_Tata' → 'truck' in 1150.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1150.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1150.xml
# Updated 'motorcycle_TVS_ApacheRTR160' → 'motorcycle' in 1151.xml
# Updated 'car_Toyota_Etios' → 'car' in 1151.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1151.xml
# Updated 'car_MarutiSuzuki_VitaraBrezza' → 'car' in 1151.xml
# Updated 'car_Ford_Figo' → 'car' in 1151.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1151.xml
# Updated 'car_Skoda_Superb' → 'car' in 1151.xml
# Updated 'car_Toyota_Innova' → 'car' in 1151.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1154.xml
# Updated 'motorcycle_Yamaha_FZ25' → 'motorcycle' in 1155.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 1155.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 1155.xml
# Updated 'car_Others' → 'car' in 1157.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1157.xml
# Updated 'car_Mahindra_TUV300' → 'car' in 1157.xml
# Updated 'car_Ford_Figo' → 'car' in 1157.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 1157.xml
# Updated 'car_Others' → 'car' in 1157.xml
# Updated 'truck_Others' → 'truck' in 1158.xml
# Updated 'truck_Eicher' → 'truck' in 1158.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 1159.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1159.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1159.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1159.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1159.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 1159.xml
# Updated 'motorcycle_Hero_Hunk' → 'motorcycle' in 1159.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1160.xml
# Updated 'car_Toyota_Etios' → 'car' in 1160.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 1161.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1161.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 1161.xml
# Updated 'car_Renault_Duster' → 'car' in 1161.xml
# Updated 'car_Mahindra_Scorpio' → 'car' in 1161.xml
# Updated 'truck_Tata' → 'truck' in 1162.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 1162.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 1162.xml
# Updated 'truck_Tata' → 'truck' in 1162.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1163.xml
# Updated 'truck_Mahindra' → 'truck' in 1163.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 1163.xml
# Updated 'car_Toyota_EtiosLiva' → 'car' in 1163.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 1163.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1163.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1166.xml
# Updated 'truck_Eicher' → 'truck' in 1166.xml
# Updated 'motorcycle_Bajaj_Discover' → 'motorcycle' in 1166.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 1166.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1166.xml
# Updated 'truck_Others' → 'truck' in 1167.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1168.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1168.xml
# Updated 'motorcycle_Bajaj_CT100' → 'motorcycle' in 1168.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1168.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 1168.xml
# Updated 'car_MarutiSuzuki_VitaraBrezza' → 'car' in 1168.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1168.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1169.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 1169.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1169.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 1169.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1169.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1169.xml
# Updated 'truck_AshokLeyland' → 'truck' in 117.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 117.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1170.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1170.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1170.xml
# Updated 'scooter_Yamaha_Fascino125' → 'scooter' in 1170.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1170.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 1170.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1170.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1170.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 1170.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1170.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 1170.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1171.xml
# Updated 'truck_Eicher' → 'truck' in 1171.xml
# Updated 'car_Hyundai_Xcent' → 'car' in 1172.xml
# Updated 'motorcycle_Bajaj_Platina' → 'motorcycle' in 1173.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1173.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1173.xml
# Updated 'autorickshaw_TVS' → 'autorickshaw' in 1173.xml
# Updated 'car_Others' → 'car' in 1173.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1174.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1174.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1174.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1174.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1174.xml
# Updated 'motorcycle_Bajaj_Discover' → 'motorcycle' in 1174.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1176.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1176.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1176.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1176.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1176.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1177.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1177.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 1177.xml
# Updated 'car_MarutiSuzuki_1000' → 'car' in 1177.xml
# Updated 'car_Mahindra_Xylo' → 'car' in 1177.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1177.xml
# Updated 'truck_Mahindra' → 'truck' in 1178.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1178.xml
# Updated 'scooter_TVS_Wego' → 'scooter' in 1178.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1178.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1178.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1178.xml
# Updated 'car_TataMotors_Indica' → 'car' in 118.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 118.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 118.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 118.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1180.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1180.xml
# Updated 'truck_Eicher' → 'truck' in 1182.xml
# Updated 'car_Others' → 'car' in 1182.xml
# Updated 'truck_Others' → 'truck' in 1183.xml
# Updated 'motorcycle_TVS_ApacheRTR160' → 'motorcycle' in 1183.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1183.xml
# Updated 'scooter_Hero_Pleasure' → 'scooter' in 1185.xml
# Updated 'motorcycle_TVS_XL100' → 'motorcycle' in 1185.xml
# Updated 'truck_Eicher' → 'truck' in 1185.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 1185.xml
# Updated 'truck_BharatBenz' → 'truck' in 1185.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1185.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1185.xml
# Updated 'motorcycle_RoyalEnfield_Bullet350' → 'motorcycle' in 1185.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1185.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1186.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1186.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1186.xml
# Updated 'car_Ford_Figo' → 'car' in 1186.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1186.xml
# Updated 'car_TataMotors_Hexa' → 'car' in 1186.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1187.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1187.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1188.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1188.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1188.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1188.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1188.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 1188.xml
# Updated 'motorcycle_Bajaj_Pulsar220F' → 'motorcycle' in 1188.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 1189.xml
# Updated 'car_Toyota_Innova' → 'car' in 1189.xml
# Updated 'car_Hyundai_Creta' → 'car' in 1189.xml
# Updated 'motorcycle_Bajaj_Avenger' → 'motorcycle' in 1190.xml
# Updated 'truck_Others' → 'truck' in 1190.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1190.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1191.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1191.xml
# Updated 'car_Others' → 'car' in 1191.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 1191.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1191.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1191.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1191.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1191.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1191.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1191.xml
# Updated 'car_Toyota_Etios' → 'car' in 1192.xml
# Updated 'car_Ford_Figo' → 'car' in 1192.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1194.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1194.xml
# Updated 'motorcycle_Bajaj_Discover' → 'motorcycle' in 1194.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1194.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1194.xml
# Updated 'car_Mahindra_Scorpio' → 'car' in 1195.xml
# Updated 'car_Mahindra_Verito' → 'car' in 1195.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1196.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 1196.xml
# Updated 'car_Honda_Amaze' → 'car' in 1196.xml
# Updated 'truck_Tata' → 'truck' in 1198.xml
# Updated 'truck_Others' → 'truck' in 1198.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1198.xml
# Updated 'car_MarutiSuzuki_Ciaz' → 'car' in 1199.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1199.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1199.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 1199.xml
# Updated 'car_Hyundai_Xcent' → 'car' in 1199.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1199.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 12.xml
# Updated 'car_Toyota_Etios' → 'car' in 12.xml
# Updated 'car_TataMotors_Sumo' → 'car' in 12.xml
# Updated 'car_Hyundai_Santro' → 'car' in 12.xml
# Updated 'truck_Tata' → 'truck' in 12.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 12.xml
# Updated 'truck_AshokLeyland' → 'truck' in 120.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1200.xml
# Updated 'car_Hyundai_Creta' → 'car' in 1200.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 1200.xml
# Updated 'car_MarutiSuzuki_Ciaz' → 'car' in 1200.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1201.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1202.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 1202.xml
# Updated 'car_Toyota_Innova' → 'car' in 1202.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1203.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1203.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1204.xml
# Updated 'car_Toyota_Etios' → 'car' in 1204.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1206.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 1206.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 121.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 121.xml
# Updated 'truck_Tata' → 'truck' in 121.xml
# Updated 'motorcycle_TVS_XL100' → 'motorcycle' in 121.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 121.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 121.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1210.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1210.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1210.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 1211.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1211.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 1211.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1211.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1211.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1211.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1211.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1211.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1211.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 1213.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 1213.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1213.xml
# Updated 'car_Hyundai_Xcent' → 'car' in 1213.xml
# Updated 'car_Toyota_Innova' → 'car' in 1213.xml
# Updated 'car_Toyota_Innova' → 'car' in 1213.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 1213.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 1213.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1213.xml
# Updated 'car_Others' → 'car' in 1213.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1217.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1217.xml
# Updated 'scooter_Yamaha_Fascino125' → 'scooter' in 1217.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1217.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1218.xml
# Updated 'motorcycle_TVS_ApacheRTR160' → 'motorcycle' in 1218.xml
# Updated 'truck_BharatBenz' → 'truck' in 1218.xml
# Updated 'truck_Tata' → 'truck' in 1218.xml
# Updated 'truck_Eicher' → 'truck' in 1219.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 122.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 122.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 122.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 122.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 122.xml
# Updated 'car_Mahindra_Scorpio' → 'car' in 122.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 122.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 122.xml
# Updated 'motorcycle_TVS_Victor' → 'motorcycle' in 122.xml
# Updated 'motorcycle_Suzuki_Gixxer' → 'motorcycle' in 122.xml
# Updated 'truck_Mahindra' → 'truck' in 1221.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1221.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1221.xml
# Updated 'car_Mercedes-Benz_AmgGt4-DoorCoupe' → 'car' in 1223.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1223.xml
# Updated 'car_Hyundai_I20' → 'car' in 1223.xml
# Updated 'truck_Tata' → 'truck' in 1223.xml
# Updated 'car_Toyota_Etios' → 'car' in 1224.xml
# Updated 'car_Volkswagen_Polo' → 'car' in 1224.xml
# Updated 'car_MarutiSuzuki_Esteem2000' → 'car' in 1224.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 1224.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1226.xml
# Updated 'motorcycle_Yamaha_FZ25' → 'motorcycle' in 1226.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1227.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1227.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1227.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1227.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1228.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 1228.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1228.xml
# Updated 'car_Honda_City' → 'car' in 1228.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1229.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1229.xml
# Updated 'car_Toyota_Fortuner' → 'car' in 123.xml
# Updated 'car_Others' → 'car' in 123.xml
# Updated 'car_Hyundai_I10' → 'car' in 123.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 123.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 123.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 1230.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1230.xml
# Updated 'car_Others' → 'car' in 1230.xml
# Updated 'car_Covered' → 'car' in 1230.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1230.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1233.xml
# Updated 'motorcycle_Yamaha_FZS-FI' → 'motorcycle' in 1233.xml
# Updated 'car_Toyota_Innova' → 'car' in 1233.xml
# Updated 'car_Others' → 'car' in 1233.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1233.xml
# Updated 'car_Hyundai_I10' → 'car' in 1233.xml
# Updated 'truck_Eicher' → 'truck' in 1233.xml
# Updated 'motorcycle_KTM_Duke' → 'motorcycle' in 1233.xml
# Updated 'motorcycle_Bajaj_Avenger' → 'motorcycle' in 1234.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1235.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1235.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1235.xml
# Updated 'truck_Others' → 'truck' in 1236.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1236.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 1236.xml
# Updated 'car_Mahindra_Xylo' → 'car' in 1236.xml
# Updated 'car_Hyundai_Accent' → 'car' in 1236.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1238.xml
# Updated 'car_Toyota_Etios' → 'car' in 1238.xml
# Updated 'car_Mahindra_Scorpio' → 'car' in 1238.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 1238.xml
# Updated 'car_Others' → 'car' in 1238.xml
# Updated 'car_Hyundai_Verna' → 'car' in 124.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 124.xml
# Updated 'truck_Others' → 'truck' in 124.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 124.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 124.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 124.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1240.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 1240.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 1243.xml
# Updated 'car_Toyota_Etios' → 'car' in 1243.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1244.xml
# Updated 'car_Mahindra_XUV500' → 'car' in 1245.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 1246.xml
# Updated 'truck_Mahindra' → 'truck' in 1246.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1246.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1246.xml
# Updated 'truck_Tata' → 'truck' in 1246.xml
# Updated 'truck_Tata' → 'truck' in 1247.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 1247.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1247.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1247.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 1247.xml
# Updated 'scooter_Vespa_VXL125' → 'scooter' in 1247.xml
# Updated 'truck_AshokLeyland' → 'truck' in 1248.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 1248.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 1248.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1249.xml
# Updated 'car_Others' → 'car' in 1249.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 1249.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 125.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 125.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 125.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 125.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1250.xml
# Updated 'motorcycle_Bajaj_Pulsar220F' → 'motorcycle' in 1250.xml
# Updated 'truck_Eicher' → 'truck' in 1250.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 1250.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1250.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 1250.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1250.xml
# Updated 'motorcycle_Bajaj_Discover' → 'motorcycle' in 1250.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 1251.xml
# Updated 'car_TataMotors_Indica' → 'car' in 1251.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 1252.xml
# Updated 'car_Toyota_Corolla' → 'car' in 1252.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 1253.xml
# ...
# Updated 'scooter_Honda_Activa' → 'scooter' in 5942.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 5942.xml
# Updated 'truck_AshokLeyland' → 'truck' in 5943.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 5944.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 5944.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 5944.xml
# Updated 'scooter_Others' → 'scooter' in 5944.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5944.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5945.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 5945.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5945.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5945.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 5946.xml
# Updated 'car_MarutiSuzuki_Ertiga' → 'car' in 5946.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 5946.xml
# Updated 'car_Honda_Amaze' → 'car' in 5946.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 5947.xml
# Updated 'truck_Eicher' → 'truck' in 5947.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5948.xml
# Updated 'truck_Tata' → 'truck' in 5948.xml
# Updated 'car_MarutiSuzuki_Ertiga' → 'car' in 5948.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5948.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5949.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5949.xml
# Updated 'car_Others' → 'car' in 5949.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 5949.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 5949.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 5950.xml
# Updated 'car_Others' → 'car' in 5950.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5950.xml
# Updated 'car_Mahindra_Verito' → 'car' in 5951.xml
# Updated 'car_Honda_Jazz' → 'car' in 5951.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5953.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5953.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 5953.xml
# Updated 'car_Others' → 'car' in 5953.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 5954.xml
# Updated 'car_Toyota_Qualis' → 'car' in 5954.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5954.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 5954.xml
# Updated 'car_TataMotors_Indica' → 'car' in 5955.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 5955.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 5955.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 5955.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 5955.xml
# Updated 'scooter_Bajaj_Chetak' → 'scooter' in 5956.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 5956.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 5956.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 5957.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5958.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5958.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5958.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5958.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5958.xml
# Updated 'autorickshaw_Piaggio' → 'autorickshaw' in 5959.xml
# Updated 'car_Nissan_Micra' → 'car' in 5959.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 5959.xml
# Updated 'car_Hyundai_I10' → 'car' in 5961.xml
# Updated 'car_Toyota_EtiosLiva' → 'car' in 5961.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 5961.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5962.xml
# Updated 'car_TataMotors_Sumo' → 'car' in 5962.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5962.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 5962.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5962.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5962.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5962.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 5962.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5962.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 5963.xml
# Updated 'car_Chevrolet_Spark' → 'car' in 5964.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 5964.xml
# Updated 'truck_Tata' → 'truck' in 5964.xml
# Updated 'car_TataMotors_Indica' → 'car' in 5964.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 5964.xml
# Updated 'truck_Eicher' → 'truck' in 5964.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5964.xml
# Updated 'car_Mahindra_Bolero' → 'car' in 5965.xml
# Updated 'car_TataMotors_Zest' → 'car' in 5965.xml
# Updated 'motorcycle_TVS_ApacheRTR160' → 'motorcycle' in 5965.xml
# Updated 'car_Skoda_Rapid' → 'car' in 5965.xml
# Updated 'car_Toyota_Etios' → 'car' in 5966.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 5966.xml
# Updated 'car_Ford_Figo' → 'car' in 5967.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 5967.xml
# Updated 'scooter_Yamaha_RayZR' → 'scooter' in 5967.xml
# Updated 'car_Nissan_Micra' → 'car' in 5967.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5968.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5968.xml
# Updated 'motorcycle_Honda_Unicorn' → 'motorcycle' in 5969.xml
# Updated 'scooter_TVS_Wego' → 'scooter' in 5969.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 5969.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 5969.xml
# Updated 'motorcycle_Bajaj_Platina' → 'motorcycle' in 5970.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 5970.xml
# Updated 'car_Others' → 'car' in 5970.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 5971.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5971.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 5971.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5971.xml
# Updated 'scooter_Others' → 'scooter' in 5972.xml
# Updated 'car_Mahindra_XUV500' → 'car' in 5972.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 5972.xml
# Updated 'car_TataMotors_Indica' → 'car' in 5972.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 5973.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5973.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5973.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 5973.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5973.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5973.xml
# Updated 'motorcycle_Bajaj_Platina' → 'motorcycle' in 5973.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5973.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5973.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5973.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 5973.xml
# Updated 'car_Toyota_Innova' → 'car' in 5974.xml
# Updated 'car_Ford_Ecosport' → 'car' in 5974.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 5975.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 5975.xml
# Updated 'car_Chevrolet_Beat' → 'car' in 5975.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 5975.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5975.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 5977.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 5977.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 5977.xml
# Updated 'truck_Mahindra' → 'truck' in 5977.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 5977.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 5977.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5977.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5977.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5978.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 5978.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 5978.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 5978.xml
# Updated 'scooter_TVS_Wego' → 'scooter' in 5979.xml
# Updated 'car_MarutiSuzuki_Ertiga' → 'car' in 5979.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 5979.xml
# Updated 'car_MarutiSuzuki_Swift' → 'car' in 5979.xml
# Updated 'car_Honda_Amaze' → 'car' in 5979.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5979.xml
# Updated 'car_Hyundai_Santro' → 'car' in 5979.xml
# Updated 'car_Renault_Duster' → 'car' in 5979.xml
# Updated 'car_Toyota_Innova' → 'car' in 5979.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 5980.xml
# Updated 'truck_Eicher' → 'truck' in 5980.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5980.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5980.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 5980.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 5980.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5980.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 5980.xml
# Updated 'truck_Others' → 'truck' in 5981.xml
# Updated 'car_Bmw_2-Series-220d' → 'car' in 5981.xml
# Updated 'car_Covered' → 'car' in 5981.xml
# Updated 'autorickshaw_Atul' → 'autorickshaw' in 5981.xml
# Updated 'car_Renault_Duster' → 'car' in 5981.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5981.xml
# Updated 'truck_Mahindra' → 'truck' in 5982.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5982.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5982.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5982.xml
# Updated 'truck_AshokLeyland' → 'truck' in 5982.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5982.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5982.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5982.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5982.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5982.xml
# Updated 'motorcycle_Honda_Shine' → 'motorcycle' in 5982.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 5982.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 5983.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 5983.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 5983.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5983.xml
# Updated 'car_MarutiSuzuki_Ciaz' → 'car' in 5984.xml
# Updated 'car_Toyota_Innova' → 'car' in 5984.xml
# Updated 'motorcycle_RoyalEnfield_Classic350' → 'motorcycle' in 5984.xml
# Updated 'car_Hyundai_Xcent' → 'car' in 5984.xml
# Updated 'motorcycle_Hero_Splendor' → 'motorcycle' in 5984.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 5984.xml
# Updated 'truck_Others' → 'truck' in 5985.xml
# Updated 'car_TataMotors_Indica' → 'car' in 5985.xml
# Updated 'car_Hyundai_Verna' → 'car' in 5985.xml
# Updated 'truck_Others' → 'truck' in 5985.xml
# Updated 'car_Toyota_Etios' → 'car' in 5985.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 5985.xml
# Updated 'motorcycle_Bajaj_Discover' → 'motorcycle' in 5986.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 5986.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5986.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 5986.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5986.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 5986.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 5987.xml
# Updated 'car_TataMotors_Indica' → 'car' in 5987.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 5987.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 5987.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5987.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5987.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5988.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5988.xml
# Updated 'truck_Mahindra' → 'truck' in 5988.xml
# Updated 'motorcycle_Bajaj_Discover135' → 'motorcycle' in 5988.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5988.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5988.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5988.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5988.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 5989.xml
# Updated 'truck_Tata' → 'truck' in 5989.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5989.xml
# Updated 'scooter_Hero_Maestro' → 'scooter' in 5989.xml
# Updated 'truck_Others' → 'truck' in 5990.xml
# Updated 'scooter_TVS_Jupiter' → 'scooter' in 5990.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 5991.xml
# Updated 'car_Toyota_Etios' → 'car' in 5991.xml
# Updated 'truck_Tata' → 'truck' in 5991.xml
# Updated 'motorcycle_Others' → 'motorcycle' in 5992.xml
# Updated 'car_TataMotors_Indica' → 'car' in 5992.xml
# Updated 'motorcycle_TVS_StarCityPlus' → 'motorcycle' in 5992.xml
# Updated 'truck_Others' → 'truck' in 5992.xml
# Updated 'car_Toyota_Innova' → 'car' in 5993.xml
# Updated 'car_Nissan_Micra' → 'car' in 5993.xml
# Updated 'car_Fiat_PuntoEvo' → 'car' in 5993.xml
# Updated 'motorcycle_TVS_Sport' → 'motorcycle' in 5994.xml
# Updated 'motorcycle_Hero_HFDeluxe' → 'motorcycle' in 5994.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 5994.xml
# Updated 'car_TataMotors_Indica' → 'car' in 5995.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 5995.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5996.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5996.xml
# Updated 'motorcycle_TVS_XL100' → 'motorcycle' in 5996.xml
# Updated 'car_Hyundai_I10' → 'car' in 5998.xml
# Updated 'car_Mahindra_XUV500' → 'car' in 5998.xml
# Updated 'truck_Tata' → 'truck' in 5999.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 5999.xml
# Updated 'motorcycle_Bajaj_V12' → 'motorcycle' in 5999.xml
# Updated 'car_MarutiSuzuki_Alto800' → 'car' in 6000.xml
# Updated 'motorcycle_TVS_XL100' → 'motorcycle' in 6000.xml
# Updated 'car_TataMotors_Indica' → 'car' in 6000.xml
# Updated 'car_Hyundai_I10' → 'car' in 6000.xml
# Updated 'truck_Eicher' → 'truck' in 6000.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 6001.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 6001.xml
# Updated 'car_Toyota_Etios' → 'car' in 6001.xml
# Updated 'motorcycle_Bajaj_Pulsar150' → 'motorcycle' in 6001.xml
# Updated 'scooter_Honda_Dio' → 'scooter' in 6001.xml
# Updated 'car_Hyundai_Santro' → 'car' in 6001.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 6002.xml
# Updated 'motorcycle_Hero_PassionPlus' → 'motorcycle' in 6002.xml
# Updated 'truck_AshokLeyland' → 'truck' in 6002.xml
# Updated 'truck_AshokLeyland' → 'truck' in 6002.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 6003.xml
# Updated 'truck_Others' → 'truck' in 6003.xml
# Updated 'car_MarutiSuzuki_WagonR' → 'car' in 6004.xml
# Updated 'car_Toyota_Etios' → 'car' in 6004.xml
# Updated 'car_Nissan_Micra' → 'car' in 6004.xml
# Updated 'car_MarutiSuzuki_Baleno' → 'car' in 6004.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 6004.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 6005.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 6005.xml
# Updated 'car_Others' → 'car' in 6005.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 6006.xml
# Updated 'scooter_TVS_Pep' → 'scooter' in 6006.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 6006.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 6006.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 6006.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 6006.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 6008.xml
# Updated 'motorcycle_Hero_Glamour' → 'motorcycle' in 6008.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 6008.xml
# Updated 'autorickshaw_Others' → 'autorickshaw' in 6008.xml
# Updated 'motorcycle_Hero_PassionPro' → 'motorcycle' in 6008.xml
# Updated 'truck_Mahindra' → 'truck' in 6008.xml
# Updated 'truck_Others' → 'truck' in 6008.xml
# Updated 'truck_Eicher' → 'truck' in 6009.xml
# Updated 'car_TataMotors_Indica' → 'car' in 6009.xml
# Updated 'car_Toyota_Etios' → 'car' in 6009.xml
# Updated 'autorickshaw_Bajaj' → 'autorickshaw' in 6011.xml
# Updated 'car_Others' → 'car' in 6011.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 6011.xml
# Updated 'scooter_Honda_Activa' → 'scooter' in 6011.xml
# Updated 'car_MarutiSuzuki_Omni' → 'car' in 6011.xml
# Updated 'motorcycle_Honda_CBHornet160R' → 'motorcycle' in 6011.xml
# Updated 'mini-bus_Others' → 'mini-bus' in 6011.xml
# Updated 'motorcycle_Yamaha_FZ-V3' → 'motorcycle' in 6011.xml
# Updated 'car_Hyundai_I10' → 'car' in 6011.xml
# Updated 'car_MarutiSuzuki_Dzire' → 'car' in 6011.xml
# Updated 'motorcycle_Yamaha_FZ-V3' → 'motorcycle' in 6011.xml
# Updated 'car_Others' → 'car' in 6011.xml
# Updated 'car_TataMotors_Sumo' → 'car' in 6011.xml
# Updated 'car_TataMotors_Indica' → 'car' in 6012.xml
# Updated 'motorcycle_Hero_Passion' → 'motorcycle' in 6012.xml
# Updated 'car_MarutiSuzuki_Ritz' → 'car' in 6012.xml
# Updated 'scooter_Suzuki_Access' → 'scooter' in 6012.xml
# Updated 'car_Honda_Amaze' → 'car' in 6012.xml
# Updated 'truck_Mahindra' → 'truck' in 6012.xml
#
# ✅ All XML files updated!

# %%
import os
import xml.etree.ElementTree as ET
import json

def xml_to_json(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()
    
    annotation = {'image': root.find('filename').text, 'annos': []}
    
    for obj in root.findall('object'):
        bbox = obj.find('bndbox')
        annotation['annos'].append({
            'class': obj.find('name').text,
            'bbox': [
                float(bbox.find('xmin').text),
                float(bbox.find('ymin').text),
                float(bbox.find('xmax').text),
                float(bbox.find('ymax').text)
            ]
        })
    
    return annotation

def convert_folder_to_json(split_path, json_output_dir):
    annos_path = os.path.join(split_path, 'annos')
    os.makedirs(json_output_dir, exist_ok=True)

    for xml_file in os.listdir(annos_path):
        if xml_file.endswith('.xml'):
            xml_path = os.path.join(annos_path, xml_file)
            json_data = xml_to_json(xml_path)

            json_filename = xml_file.replace('.xml', '.json')
            with open(os.path.join(json_output_dir, json_filename), 'w') as jf:
                json.dump(json_data, jf, indent=2)

base_path = r'C:\Users\Sejal Hanmante\OneDrive\Desktop\idd detection\IDD_FGVD'
splits = ['train', 'val', 'test']

for split in splits:
    split_path = os.path.join(base_path, split)
    json_output_dir = os.path.join(base_path, f'{split}_json')
    convert_folder_to_json(split_path, json_output_dir)
